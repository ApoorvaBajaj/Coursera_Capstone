# %% [markdown]
# # Opening a Restaurant in South Indian City of Chennai
#
# ## Capstone Project_IBM_Coursera_Apoorva Bajaj_Week 1_Notebook
#
# ### Section Index (Week 1)
#
# 1. [Section 1: Introduction: Background and Problem Discussion](#intro)
# 2. [Section 2: Data Description and Requirements](#data)

# %% [markdown]
# ## Introduction: Background and Problem Discussion <a name="intro"></a>

# %% [markdown]
# I am from India, one of my close friends stays in Chennai. He wants to open a restaurant in Chennai. He is not sure what parameters to consider while choosing a perfect location for his restaurant project in Chennai. I am helping him with data-driven decision-making using Data science. This Capstone project will explore the neighbourhoods of Chennai, a city in the Southern Part of India. I am of the opinion, that this project, its results and conclusions will be helpful for my friend who is planning to open a Restaurant in Chennai and would also be helpful to someone who is thinking of opening a similar food-outlet in Chennai.
#
# For the purpose of this project, I will be using “Foursquare API” to explore the neighbourhoods of Chennai. Specifically, I am interested in analysing the neighbourhood areas for which several venues can be obtained. Using Data Science methodologies, they are clustered based on the venues. I will be using “k-means clustering algorithm” to achieve the task. The optimal number of clusters will be gathered using silhouette score. I will be using “Folium visualization library** to visualize the clusters superimposed on the map of the city of Chennai. These clusters can be analysed to provide data driven and visual insights to my friend or other small scale businesses to select an apt location for their requirement, such as Restaurants or Hotels.

# %% [markdown]
# #### Importing the libraries relevant for this project

# %%
import re
import json
import requests
import numpy as np
from bs4 import BeautifulSoup

import pandas as pd
#display all rows
pd.set_option('display.max_rows', None)
#display all columns
pd.set_option('display.max_columns', None)

from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_samples, silhouette_score

from geopy.geocoders import Nominatim

import folium

import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt
# %matplotlib inline

print('Libraries imported.')
# Out:
# Libraries imported.

# %% [markdown]
# ## Data Description and Requirements <a name="data"></a>

# %% [markdown]
# Chennai has several neighbourhoods. I have found this dataset: https://chennaiiq.com/chennai/latitude_longitude_areas.asp  which includes the list of locations in Chennai city along with their Latitude and Longitude co-ordinates.
# One thing to note is that the Latitude and Longitude data provided in this link is in Degrees, Minutes and Seconds format. This has to be converted to Decimal Degrees before starting the analysis.

# %%
url = 'https://chennaiiq.com/chennai/latitude_longitude_areas.asp'

html = requests.get(url)
print(html)
# Out:
# <Response [200]>

# %% [markdown]
# A Reponse value of 200 means that this process was successful. Now we will clean the file to access the Neighborhoods and their Locations. Using BeautifulSoup library,I will parse the html file to make it easier to access.

# %%
soup = BeautifulSoup(html.text, 'html.parser')
table = soup.find("table", attrs={"class": "TBox"})

# %% [markdown]
# The html has been parsed and it can be used to build the dataset. As a next step, I will access the Location data and store it in a pandas dataframe: chennai_data.
#
# #### Data Collection:

# %%
table_data = []
index = ['S.No.', 'Location', 'Latitude', 'Longitude']
for tr in table.find_all("tr", attrs={"class": "tab"}):
    t_row = {}
    for td, th in zip(tr.find_all("td"), index): 
        t_row[th] = td.text.replace('\n', '').strip()
    table_data.append(t_row)

chennai_data = pd.DataFrame(table_data[:-1], columns=index)
chennai_data.drop(columns=['S.No.'], inplace=True)
chennai_data.at[0,'Location'] = 'Adyar Bus Debot'
chennai_data.rename(columns={'Location': 'Neighborhood'}, inplace=True)
print(chennai_data.shape)
chennai_data.head()
# Out:
# (105, 3)
#       Neighborhood     Latitude    Longitude
# 0  Adyar Bus Debot  12°59'50" N  80°15'25" E
# 1     Adyar Signal  13°00'23" N  80°15'27" E
# 2          Alandur  13°00'28" N  80°12'35" E
# 3         Ambattur  13°06'36" N  80°10'12" E
# 4        Anna Arch  13°04'28" N  80°13'06" E

# %% [markdown]
# #### Data Conversion: Converting Degrees, Minute and Seconds to Decimal Degrees

# %% [markdown]
# There are a total of 105 neighborhoods. But as noted earlier the Latitude and Longitude data needs to be converted from Degrees, Minute & Seconds to Decimal Degrees. The dms2dd function as used below will solve this problem.

# %%
def dms2dd(s):
    degrees, minutes, seconds, direction = re.split('[°\'"]+', s)
    dd = float(degrees) + float(minutes)/60 + float(seconds)/(60*60);
    if direction in ('S','W'):
        dd*= -1
    return dd

chennai_data['Latitude'] = chennai_data['Latitude'].apply(dms2dd)
chennai_data['Longitude'] = chennai_data['Longitude'].apply(dms2dd)
print(chennai_data.shape)
chennai_data.head()
# Out:
# (105, 3)
#       Neighborhood   Latitude  Longitude
# 0  Adyar Bus Debot  12.997222  80.256944
# 1     Adyar Signal  13.006389  80.257500
# 2          Alandur  13.007778  80.209722
# 3         Ambattur  13.110000  80.170000
# 4        Anna Arch  13.074444  80.218333

# %% [markdown]
# Now that we have the neighborhoods dataset lets visualize them using Folium Library. First lets create a map of Chennai. The latitude and longitude of chennai can be obtained using the Geolocator library.

# %%
address = 'Chennai, Tamil Nadu'

geolocator = Nominatim(user_agent="chennai_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geographical coordinate of chennai are {}, {}.'.format(latitude, longitude))
# Out:
# The geographical coordinate of chennai are 13.0801721, 80.2838331.

# %% [markdown]
# #### Chennai Map:

# %%
# create map of Toronto using latitude and longitude values
chennai_map = folium.Map(location=[latitude, longitude], zoom_start=11)    
chennai_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Chennai Map with the neighborhoods superimposed on top:

# %%
# add neighborhood markers to map
for lat, lng, location in zip(chennai_data['Latitude'], chennai_data['Longitude'], chennai_data['Neighborhood']):
    label = '{}'.format(location)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(chennai_map)  

chennai_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Define Foursquare Credentials and Version

# %%
CLIENT_ID = '' # your Foursquare ID
CLIENT_SECRET = '' # your Foursquare Secret
VERSION = '20210627' # Foursquare API version

# %% [markdown]
# #### Explore neighborhoods in Chennai

# %% [markdown]
# The following function will send an explore request for each neighborhood and return the 100 most popular places in the neighborhood around 500 meters.

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500, limit=100):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            limit)
            
        # make the GET request
        count = 1
        while count != 5:
            try:
                results = requests.get(url).json()["response"]['groups'][0]['items']
                count = 5
            except:
                count += 1
    
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# Lets use the above function on the chennai_data neighborhoods dataframe and store the venues data returned in the chennai_venues pandas dataframe.

# %%
chennai_venues = getNearbyVenues(names = chennai_data['Neighborhood'],
                                 latitudes = chennai_data['Latitude'],
                                 longitudes = chennai_data['Longitude']
                                 )

print(chennai_venues.shape)
chennai_venues.head()
# Out:
# (1130, 7)
#       Neighborhood  Neighborhood Latitude  Neighborhood Longitude  \
# 0  Adyar Bus Debot              12.997222               80.256944
# 1  Adyar Bus Debot              12.997222               80.256944
# 2  Adyar Bus Debot              12.997222               80.256944
# 3  Adyar Bus Debot              12.997222               80.256944
# 4  Adyar Bus Debot              12.997222               80.256944
#
#                                Venue  Venue Latitude  Venue Longitude  \
# 0                 Zaitoon Restaurant       12.996861        80.256178
# 1               Kuttanadu Restaurant       12.997010        80.257799
# 2                           Zha Cafe       12.999730        80.254806
# 3  Adyar Ananda Bhavan, Besant Nagar       12.996678        80.258275
# 4           Kovai Pazhamudir Nilayam       12.996522        80.259776
#
#               Venue Category
# 0  Middle Eastern Restaurant
# 1           Asian Restaurant
# 2                       Café
# 3       Fast Food Restaurant
# 4    Fruit & Vegetable Store

# %% [markdown]
# A total of 1130 venues were obtained. Now lets check the number of venues returned per neighborhood.

# %%
chennai_venues.groupby('Neighborhood').count()
# Out:
#                                         Neighborhood Latitude  \
# Neighborhood
# AVM Studio                                                  4
# Adyar Bus Debot                                            16
# Adyar Signal                                               32
# Alandur                                                    11
# Ambattur                                                    1
# Anna Arch                                                  14
# Anna Nagar Roundana                                        21
# Anna Nagar West Terminus                                    7
# Anna Statue                                                11
# Anna University Entrance                                    4
# Avadi                                                       1
# Ayyappa Temple                                              7
# Basin Bridge                                                2
# CIPET                                                       3
# CIT Nagar Roundana                                          7
# CLRI                                                        7
# Chennai Airport                                             1
# Chennai Central                                            17
# Chennai Mofussil Bus Terminas (CMBT)                        6
# Chennai Trade Center                                        6
# Chepaukam Stadium                                          13
# Chintadripet                                                4
# Chintamani Signal                                          12
# Chola                                                      36
# Church Park                                                33
# DPI                                                         7
# Egmore Railway Station                                      7
# Ethiraj College                                            22
# Gemini Flyover                                             24
# Greams Road                                                31
# Guindy Race Course                                          3
# Guindy Railway Station                                      6
# HTL Colony                                                  4
# IIT Madras                                                  5
# Indra Nagar, Adyar                                         10
# Isphani                                                    38
# Kamarajar Arangam                                          21
# Kapaleeswarar Temple                                        2
# Kasi Viswanathar Temple                                     4
# Kasturiba Nagar, Adyar                                      7
# Kathipara Junction                                          6
# Kodampakkam                                                 5
# Korukkupet                                                  4
# Koyambedu Omni Bus Terminus                                 6
# Koyambedu Super Market                                      2
# Le Meridian                                                 6
# Light House                                                19
# Loyolo College                                              9
# MIOT Hospital                                               9
# MMM Hospital                                                8
# MRTS                                                        7
# Madhavaram                                                  4
# Madhya Kailash                                              6
# Mambalam                                                   11
# Minambakkam                                                 7
# Mugappair East Terminus                                     4
# Mugappair West                                              4
# Music Academy                                              36
# Nandanam Signal                                             5
# Nanganallur                                                 5
# Nehru Nagar, Adyar                                         17
# Newaharlal Nehru Stadium                                   11
# Nungampakkam Railway Station                                9
# Panagal Park                                               30
# Park Sheraton Hotel                                        33
# Parrys Bus Stand                                            4
# Parthasarathy Temple                                        5
# Pazhavanthangal                                             4
# Perambur Loco Works                                         3
# Planetarium                                                 5
# Poonamallee                                                 1
# Ramachandra Medical College & Hospital                      2
# Royapuram                                                   6
# Saidapet Bus Terminus                                       4
# Saidapet Court                                              9
# Shastri Bhavan                                             14
# Sri Kothanda Ramaswamy Temple                               5
# St. Thomas Mount                                            3
# Stella Maris                                               28
# T. Nagar Bus Terminus                                       6
# TVS Signal                                                  5
# Taj Coromandal                                             50
# Temple Tower                                                7
# Teynampet Signal                                           24
# Tharamani                                                   8
# The US Consulate                                           24
# Thirumangalam Signal                                       13
# Thiruvanmiyur                                               1
# Thiruvanmiyur Bus Terminus                                  9
# Thiruvanmiyur Junction                                     10
# Tidel Park                                                 19
# Tiruvottiyur                                                3
# Tondiarpet                                                  1
# Triplicane                                                 12
# Triplicane Railway Station                                  4
# Vadapalani Signal                                          26
# Valluvar Kottam                                             6
# Vani Mahal                                                 20
# Velachery Bus Terminus                                     31
# Vyasar Padi                                                 1
# Washermanpet                                                1
# Woodlands Drive In                                         19
# chetput                                                     7
#
#                                         Neighborhood Longitude  Venue  \
# Neighborhood
# AVM Studio                                                   4      4
# Adyar Bus Debot                                             16     16
# Adyar Signal                                                32     32
# Alandur                                                     11     11
# Ambattur                                                     1      1
# Anna Arch                                                   14     14
# Anna Nagar Roundana                                         21     21
# Anna Nagar West Terminus                                     7      7
# Anna Statue                                                 11     11
# Anna University Entrance                                     4      4
# Avadi                                                        1      1
# Ayyappa Temple                                               7      7
# Basin Bridge                                                 2      2
# CIPET                                                        3      3
# CIT Nagar Roundana                                           7      7
# CLRI                                                         7      7
# Chennai Airport                                              1      1
# Chennai Central                                             17     17
# Chennai Mofussil Bus Terminas (CMBT)                         6      6
# Chennai Trade Center                                         6      6
# Chepaukam Stadium                                           13     13
# Chintadripet                                                 4      4
# Chintamani Signal                                           12     12
# Chola                                                       36     36
# Church Park                                                 33     33
# DPI                                                          7      7
# Egmore Railway Station                                       7      7
# Ethiraj College                                             22     22
# Gemini Flyover                                              24     24
# Greams Road                                                 31     31
# Guindy Race Course                                           3      3
# Guindy Railway Station                                       6      6
# HTL Colony                                                   4      4
# IIT Madras                                                   5      5
# Indra Nagar, Adyar                                          10     10
# Isphani                                                     38     38
# Kamarajar Arangam                                           21     21
# Kapaleeswarar Temple                                         2      2
# Kasi Viswanathar Temple                                      4      4
# Kasturiba Nagar, Adyar                                       7      7
# Kathipara Junction                                           6      6
# Kodampakkam                                                  5      5
# Korukkupet                                                   4      4
# Koyambedu Omni Bus Terminus                                  6      6
# Koyambedu Super Market                                       2      2
# Le Meridian                                                  6      6
# Light House                                                 19     19
# Loyolo College                                               9      9
# MIOT Hospital                                                9      9
# MMM Hospital                                                 8      8
# MRTS                                                         7      7
# Madhavaram                                                   4      4
# Madhya Kailash                                               6      6
# Mambalam                                                    11     11
# Minambakkam                                                  7      7
# Mugappair East Terminus                                      4      4
# Mugappair West                                               4      4
# Music Academy                                               36     36
# Nandanam Signal                                              5      5
# Nanganallur                                                  5      5
# Nehru Nagar, Adyar                                          17     17
# Newaharlal Nehru Stadium                                    11     11
# Nungampakkam Railway Station                                 9      9
# Panagal Park                                                30     30
# Park Sheraton Hotel                                         33     33
# Parrys Bus Stand                                             4      4
# Parthasarathy Temple                                         5      5
# Pazhavanthangal                                              4      4
# Perambur Loco Works                                          3      3
# Planetarium                                                  5      5
# Poonamallee                                                  1      1
# Ramachandra Medical College & Hospital                       2      2
# Royapuram                                                    6      6
# Saidapet Bus Terminus                                        4      4
# Saidapet Court                                               9      9
# Shastri Bhavan                                              14     14
# Sri Kothanda Ramaswamy Temple                                5      5
# St. Thomas Mount                                             3      3
# Stella Maris                                                28     28
# T. Nagar Bus Terminus                                        6      6
# TVS Signal                                                   5      5
# Taj Coromandal                                              50     50
# Temple Tower                                                 7      7
# Teynampet Signal                                            24     24
# Tharamani                                                    8      8
# The US Consulate                                            24     24
# Thirumangalam Signal                                        13     13
# Thiruvanmiyur                                                1      1
# Thiruvanmiyur Bus Terminus                                   9      9
# Thiruvanmiyur Junction                                      10     10
# Tidel Park                                                  19     19
# Tiruvottiyur                                                 3      3
# Tondiarpet                                                   1      1
# Triplicane                                                  12     12
# Triplicane Railway Station                                   4      4
# Vadapalani Signal                                           26     26
# Valluvar Kottam                                              6      6
# Vani Mahal                                                  20     20
# Velachery Bus Terminus                                      31     31
# Vyasar Padi                                                  1      1
# Washermanpet                                                 1      1
# Woodlands Drive In                                          19     19
# chetput                                                      7      7
#
#                                         Venue Latitude  Venue Longitude  \
# Neighborhood
# AVM Studio                                           4                4
# Adyar Bus Debot                                     16               16
# Adyar Signal                                        32               32
# Alandur                                             11               11
# Ambattur                                             1                1
# Anna Arch                                           14               14
# Anna Nagar Roundana                                 21               21
# Anna Nagar West Terminus                             7                7
# Anna Statue                                         11               11
# Anna University Entrance                             4                4
# Avadi                                                1                1
# Ayyappa Temple                                       7                7
# Basin Bridge                                         2                2
# CIPET                                                3                3
# CIT Nagar Roundana                                   7                7
# CLRI                                                 7                7
# Chennai Airport                                      1                1
# Chennai Central                                     17               17
# Chennai Mofussil Bus Terminas (CMBT)                 6                6
# Chennai Trade Center                                 6                6
# Chepaukam Stadium                                   13               13
# Chintadripet                                         4                4
# Chintamani Signal                                   12               12
# Chola                                               36               36
# Church Park                                         33               33
# DPI                                                  7                7
# Egmore Railway Station                               7                7
# Ethiraj College                                     22               22
# Gemini Flyover                                      24               24
# Greams Road                                         31               31
# Guindy Race Course                                   3                3
# Guindy Railway Station                               6                6
# HTL Colony                                           4                4
# IIT Madras                                           5                5
# Indra Nagar, Adyar                                  10               10
# Isphani                                             38               38
# Kamarajar Arangam                                   21               21
# Kapaleeswarar Temple                                 2                2
# Kasi Viswanathar Temple                              4                4
# Kasturiba Nagar, Adyar                               7                7
# Kathipara Junction                                   6                6
# Kodampakkam                                          5                5
# Korukkupet                                           4                4
# Koyambedu Omni Bus Terminus                          6                6
# Koyambedu Super Market                               2                2
# Le Meridian                                          6                6
# Light House                                         19               19
# Loyolo College                                       9                9
# MIOT Hospital                                        9                9
# MMM Hospital                                         8                8
# MRTS                                                 7                7
# Madhavaram                                           4                4
# Madhya Kailash                                       6                6
# Mambalam                                            11               11
# Minambakkam                                          7                7
# Mugappair East Terminus                              4                4
# Mugappair West                                       4                4
# Music Academy                                       36               36
# Nandanam Signal                                      5                5
# Nanganallur                                          5                5
# Nehru Nagar, Adyar                                  17               17
# Newaharlal Nehru Stadium                            11               11
# Nungampakkam Railway Station                         9                9
# Panagal Park                                        30               30
# Park Sheraton Hotel                                 33               33
# Parrys Bus Stand                                     4                4
# Parthasarathy Temple                                 5                5
# Pazhavanthangal                                      4                4
# Perambur Loco Works                                  3                3
# Planetarium                                          5                5
# Poonamallee                                          1                1
# Ramachandra Medical College & Hospital               2                2
# Royapuram                                            6                6
# Saidapet Bus Terminus                                4                4
# Saidapet Court                                       9                9
# Shastri Bhavan                                      14               14
# Sri Kothanda Ramaswamy Temple                        5                5
# St. Thomas Mount                                     3                3
# Stella Maris                                        28               28
# T. Nagar Bus Terminus                                6                6
# TVS Signal                                           5                5
# Taj Coromandal                                      50               50
# Temple Tower                                         7                7
# Teynampet Signal                                    24               24
# Tharamani                                            8                8
# The US Consulate                                    24               24
# Thirumangalam Signal                                13               13
# Thiruvanmiyur                                        1                1
# Thiruvanmiyur Bus Terminus                           9                9
# Thiruvanmiyur Junction                              10               10
# Tidel Park                                          19               19
# Tiruvottiyur                                         3                3
# Tondiarpet                                           1                1
# Triplicane                                          12               12
# Triplicane Railway Station                           4                4
# Vadapalani Signal                                   26               26
# Valluvar Kottam                                      6                6
# Vani Mahal                                          20               20
# Velachery Bus Terminus                              31               31
# Vyasar Padi                                          1                1
# Washermanpet                                         1                1
# Woodlands Drive In                                  19               19
# chetput                                              7                7
#
#                                         Venue Category
# Neighborhood
# AVM Studio                                           4
# Adyar Bus Debot                                     16
# Adyar Signal                                        32
# Alandur                                             11
# Ambattur                                             1
# Anna Arch                                           14
# Anna Nagar Roundana                                 21
# Anna Nagar West Terminus                             7
# Anna Statue                                         11
# Anna University Entrance                             4
# Avadi                                                1
# Ayyappa Temple                                       7
# Basin Bridge                                         2
# CIPET                                                3
# CIT Nagar Roundana                                   7
# CLRI                                                 7
# Chennai Airport                                      1
# Chennai Central                                     17
# Chennai Mofussil Bus Terminas (CMBT)                 6
# Chennai Trade Center                                 6
# Chepaukam Stadium                                   13
# Chintadripet                                         4
# Chintamani Signal                                   12
# Chola                                               36
# Church Park                                         33
# DPI                                                  7
# Egmore Railway Station                               7
# Ethiraj College                                     22
# Gemini Flyover                                      24
# Greams Road                                         31
# Guindy Race Course                                   3
# Guindy Railway Station                               6
# HTL Colony                                           4
# IIT Madras                                           5
# Indra Nagar, Adyar                                  10
# Isphani                                             38
# Kamarajar Arangam                                   21
# Kapaleeswarar Temple                                 2
# Kasi Viswanathar Temple                              4
# Kasturiba Nagar, Adyar                               7
# Kathipara Junction                                   6
# Kodampakkam                                          5
# Korukkupet                                           4
# Koyambedu Omni Bus Terminus                          6
# Koyambedu Super Market                               2
# Le Meridian                                          6
# Light House                                         19
# Loyolo College                                       9
# MIOT Hospital                                        9
# MMM Hospital                                         8
# MRTS                                                 7
# Madhavaram                                           4
# Madhya Kailash                                       6
# Mambalam                                            11
# Minambakkam                                          7
# Mugappair East Terminus                              4
# Mugappair West                                       4
# Music Academy                                       36
# Nandanam Signal                                      5
# Nanganallur                                          5
# Nehru Nagar, Adyar                                  17
# Newaharlal Nehru Stadium                            11
# Nungampakkam Railway Station                         9
# Panagal Park                                        30
# Park Sheraton Hotel                                 33
# Parrys Bus Stand                                     4
# Parthasarathy Temple                                 5
# Pazhavanthangal                                      4
# Perambur Loco Works                                  3
# Planetarium                                          5
# Poonamallee                                          1
# Ramachandra Medical College & Hospital               2
# Royapuram                                            6
# Saidapet Bus Terminus                                4
# Saidapet Court                                       9
# Shastri Bhavan                                      14
# Sri Kothanda Ramaswamy Temple                        5
# St. Thomas Mount                                     3
# Stella Maris                                        28
# T. Nagar Bus Terminus                                6
# TVS Signal                                           5
# Taj Coromandal                                      50
# Temple Tower                                         7
# Teynampet Signal                                    24
# Tharamani                                            8
# The US Consulate                                    24
# Thirumangalam Signal                                13
# Thiruvanmiyur                                        1
# Thiruvanmiyur Bus Terminus                           9
# Thiruvanmiyur Junction                              10
# Tidel Park                                          19
# Tiruvottiyur                                         3
# Tondiarpet                                           1
# Triplicane                                          12
# Triplicane Railway Station                           4
# Vadapalani Signal                                   26
# Valluvar Kottam                                      6
# Vani Mahal                                          20
# Velachery Bus Terminus                              31
# Vyasar Padi                                          1
# Washermanpet                                         1
# Woodlands Drive In                                  19
# chetput                                              7

# %% [markdown]
# From the above dataframe we can see that Taj Coromandal returned the highest number of venues i.e. 50. Now lets check the unique categories of all the venues returned.

# %%
print('There are {} uniques categories.'.format(len(chennai_venues['Venue Category'].unique())))
# Out:
# There are 145 uniques categories.
